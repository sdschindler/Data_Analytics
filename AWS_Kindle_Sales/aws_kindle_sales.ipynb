# %% [markdown]
# # Kindle Sales Analysis

# %% [markdown]
# ## Step 1: Import Libraries

# %%
import pandas as pd
import psycopg2

# %% [markdown]
# ## Step 2: Assinging Credentials

# %%
host = 'capstoneworkgroup.637423452511.us-east-2.redshift-serverless.amazonaws.com'
port = '5439'
database = 'dev'
user = 'admin'
password = 'redacted'

# %% [markdown]
# ## Step 3: Establish Connection to Redshift

# %%
conn = psycopg2.connect(dbname = database,user = user,password = password,host = host,port = port
)

# %% [markdown]
# ## Step 4: Define SQL Query

# %%
sql_query = """

SELECT
    *
FROM
    "dev"."capstoneschema"."kindlefolder";
"""

# %%
df= pd.read_sql_query(sql_query,conn)
# Out:
# /var/folders/qq/6j6g0yz144sd_nphs7xty6tw0000gn/T/ipykernel_39614/1531987549.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df= pd.read_sql_query(sql_query,conn)

# %%
conn.close()

# %% [markdown]
# ## Step 5: EDA

# %%
df.head()
# Out:
#          asin                                              title  \
# 0  B00TZE87S4  Adult Children of Emotionally Immature Parents...
# 1  B08WCKY8MB  From Strength to Strength: Finding Success, Ha...
# 2  B09KPS84CJ  Good Inside: A Guide to Becoming the Parent Yo...
# 3  B07S7QPG6J             Everything I Know About Love: A Memoir
# 4  B00N6PEQV0  The Seven Principles for Making Marriage Work:...
#
#               author                    soldBy  \
# 0  Lindsay C. Gibson   Amazon.com Services LLC
# 1   Arthur C. Brooks   Penguin Group (USA) LLC
# 2      Becky Kennedy  HarperCollins Publishers
# 3     Dolly Alderton  HarperCollins Publishers
# 4       John Gottman          Random House LLC
#
#                                               imgUrl  \
# 0  https://m.media-amazon.com/images/I/713KZTsaYp...
# 1  https://m.media-amazon.com/images/I/A1LZcJFs9E...
# 2  https://m.media-amazon.com/images/I/71RIWM0sv6...
# 3  https://m.media-amazon.com/images/I/71QdQpTiKZ...
# ...

# %%
df.describe()
# Out:
#                stars        reviews          price    category_id
# count  133102.000000  133102.000000  133102.000000  133102.000000
# mean        4.404090     887.375779      15.134127      16.287111
# std         0.745646    5104.878777      22.254986       8.416924
# min         0.000000       0.000000       0.000000       1.000000
# 25%         4.400000       0.000000       4.990000       9.000000
# 50%         4.500000       4.000000       9.990000      16.000000
# 75%         4.700000     365.000000      14.990000      23.000000
# max         5.000000  618227.000000     682.000000      31.000000

# %%
df = df.dropna()

# %%
df.describe()
# Out:
#               stars        reviews         price   category_id
# count  77800.000000   77800.000000  77800.000000  77800.000000
# mean       4.371353     648.976530     19.363574     15.155797
# std        0.827681    5087.894642     26.330844      8.506588
# min        0.000000       0.000000      0.000000      1.000000
# 25%        4.400000       0.000000      8.990000      9.000000
# 50%        4.500000       0.000000     11.990000     14.000000
# 75%        4.700000     192.000000     17.990000     22.000000
# max        5.000000  618227.000000    682.000000     31.000000

# %% [markdown]
# ## Step 6: Results of Analysis

# %%
group = df.groupby('author') # Authors that have published the most

# %%
group.count().sort_values(ascending=False, by ='publishedDate').head(10)
# Out:
#                          asin  title  soldBy  imgUrl  productURL  stars  \
# author
# DK Eyewitness             154    154     154     154         154    154
# Fodor's Travel Guides     111    111     111     111         111    111
# DK                         96     96      96      96          96     96
# America's Test Kitchen     73     73      73      73          73     73
# Amazon.com Services LLC    68     68      68      68          68     68
# Rough Guides               67     67      67      67          67     67
# Stephen King               56     56      56      56          56     56
# Nora Roberts               49     49      49      49          49     49
# Rick Steves                43     43      43      43          43     43
# Max Lucado                 38     38      38      38          38     38
#
#                          reviews  price  isKindleUnlimited  category_id  \
# author
# DK Eyewitness                154    154                154          154
# ...

# %%
final_df = df.sort_values(by=['price'], ascending=False) # most expensive books

# %%
final_df.head(10)
# Out:
#               asin                                              title  \
# 123336  B0CFWJB1PX  Drugs in Litigation: Damage Awards Involving P...
# 125981  B006NYK31S                           Broker-Dealer Regulation
# 123725  B017HM6F1Q                  How to Write a Patent Application
# 113257  B0C15XY3C1  The Collected Works of C. G. Jung: Revised and...
# 117647  B08B2N4WBH  The Art of Aesthetic Surgery, Three Volume Set...
# 117177  B07D7KLC8K  Perforator Flaps: Anatomy, Technique, & Clinic...
# 124945  B08R87JNC3  International Commercial Arbitration: Three Vo...
# 124152  B00C318T6G  LexisNexis Practice Guide: Florida Personal In...
# 125127  B01N7QV17T     Private Equity Funds: Formation and Operations
# 123467  B0BMM7BYZN  LexisNexis AnswerGuide New York Negligence 202...
#
#                             author                   soldBy  \
# 123336  LexisNexis Editorial Staff  Amazon.com Services LLC
# 125981          Clifford E. Kirsch  Amazon.com Services LLC
# ...

# %%
group2 = df.groupby('category_name') # Top Genres published

# %%
group2.count().sort_values(ascending=False, by ='category_id').head(10)
# Out:
#                               asin  title  author  soldBy  imgUrl  productURL  \
# category_name
# Science & Math                5047   5047    5047    5047    5047        5047
# Engineering & Transportation  4860   4860    4860    4860    4860        4860
# Biographies & Memoirs         4796   4796    4796    4796    4796        4796
# Parenting & Relationships     4441   4441    4441    4441    4441        4441
# Cookbooks, Food & Wine        4438   4438    4438    4438    4438        4438
# Computers & Technology        4412   4412    4412    4412    4412        4412
# Crafts, Hobbies & Home        4278   4278    4278    4278    4278        4278
# Travel                        4028   4028    4028    4028    4028        4028
# Law                           3991   3991    3991    3991    3991        3991
# Education & Teaching          3877   3877    3877    3877    3877        3877
#
#                               stars  reviews  price  isKindleUnlimited  \
# category_name
# ...
